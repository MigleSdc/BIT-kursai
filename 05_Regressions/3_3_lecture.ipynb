# %%
import pandas as pd
weather = pd.read_csv(r"C:\Users\migle\Desktop\Python\madrid_weather.csv")

# %%
import pandas as pd
 
weather = pd.read_csv("C:\Users\migle\Desktop\Python\madrid_weather.csv", parse_dates=["time"])
# Out:
#   Cell In[1], line 3
#     weather = pd.read_csv("C:\Users\migle\Desktop\Python\madrid_weather.csv", parse_dates=["time"])
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
weather.set_index("time").loc[:, "temperature"].plot()
# Out:
# <Axes: xlabel='time'>

# %%
weather.set_index("time").loc[:"2019-01-07", "temperature"].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 weather.set_index("time").loc[:"2019-01-07", "temperature"].plot()
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1117, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1115             return section
#    1116         # This is an elided recursive call to iloc/loc
# -> 1117         return getattr(section, self.name)[new_key]
#    1119 raise IndexingError("not applicable")
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1429, in _LocIndexer._getitem_axis(self, key, axis)
#    1427 if isinstance(key, slice):
#    1428     self._validate_key(key, axis)
# -> 1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
#    1431     return self._getbool_axis(key, axis=axis)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexing.py:1461, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1458     return obj.copy(deep=False)
#    1460 labels = obj._get_axis(axis)
# -> 1461 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1463 if isinstance(indexer, slice):
#    1464     return self.obj._slice(indexer, axis=axis)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexes\base.py:6804, in Index.slice_indexer(self, start, end, step)
#    6753 def slice_indexer(
#    6754     self,
#    6755     start: Hashable | None = None,
#    6756     end: Hashable | None = None,
#    6757     step: int | None = None,
#    6758 ) -> slice:
#    6759     """
#    6760     Compute the slice indexer for input labels and step.
#    6761
#    (...)   6802     slice(1, 3, None)
#    6803     """
# -> 6804     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6806     # return a slice
#    6807     if not is_scalar(start_slice):
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexes\base.py:7068, in Index.slice_locs(self, start, end, step)
#    7066 end_slice = None
#    7067 if end is not None:
# -> 7068     end_slice = self.get_slice_bound(end, "right")
#    7069 if end_slice is None:
#    7070     end_slice = len(self)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\indexes\base.py:6973, in Index.get_slice_bound(self, label, side)
#    6971         return self._searchsorted_monotonic(label, side)
#    6972     except ValueError:
# -> 6973         raise KeyError(
#    6974             f"Cannot get {side} slice bound for non-monotonic index "
#    6975             f"with a missing label {original_label!r}. "
#    6976             "Either sort the index or specify an existing label."
#    6977         ) from None
#    6979 if isinstance(slc, np.ndarray):
#    6980     # get_loc may return a boolean array, which
#    6981     # is OK as long as they are representable by a slice.
#    6982     assert is_bool_dtype(slc.dtype)
#
# KeyError: "Cannot get right slice bound for non-monotonic index with a missing label '2019-01-07'. Either sort the index or specify an existing label."

# %%
# 24h = daily moving average
weather.set_index("time").loc[:, "temperature"].rolling((24)).mean().plot();

# %%
# (24 * 30) = 30-day moving average
 
weather.set_index("time").loc[:, "temperature"].rolling((24 * 30)).mean().plot();

# %%
# (24 * 365) = yearly moving average
 
 
weather.set_index("time").loc[:, "temperature"].rolling((24 * 365)).mean().plot();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd

taco_stands = pd.read_csv(r"C:\Users\migle\Desktop\Python\taco_stands.csv",
                          parse_dates=["Date"])

taco_stands.tail(30)
# Out:
# C:\Users\migle\AppData\Local\Temp\ipykernel_13968\3347976406.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   taco_stands = pd.read_csv(r"C:\Users\migle\Desktop\Python\taco_stands.csv",
#           Date  Taco Stands in LA
# 210 2027-07-01                232
# 211 2027-08-01                240
# 212 2027-09-01                233
# 213 2027-10-01                231
# 214 2027-11-01                230
# 215 2027-12-01                228
# 216 2028-01-01                228
# 217 2028-02-01                231
# 218 2028-03-01                231
# 219 2028-04-01                235
# 220 2028-05-01                240
# 221 2028-06-01                245
# 222 2028-07-01                244
# 223 2028-08-01                252
# 224 2028-09-01                245
# 225 2028-10-01                243
# 226 2028-11-01                242
# 227 2028-12-01                240
# 228 2029-01-01                240
# 229 2029-02-01                243
# 230 2029-03-01                243
# 231 2029-04-01                247
# 232 2029-05-01                252
# 233 2029-06-01                257
# 234 2029-07-01                256
# 235 2029-08-01                264
# 236 2029-09-01                257
# 237 2029-10-01                255
# 238 2029-11-01                254
# 239 2029-12-01                252

# %%
taco_stands.set_index("Date").plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# full year (or full hour)
seasonal_decompose(taco_stands.set_index("Date")).plot();

# %%
# 6 months
seasonal_decompose(taco_stands.set_index("Date"), model="multiplicative", period=6).plot();

# %%
from statsmodels.graphics.tsaplots import plot_acf
 
 
#data still has trend in it
plot_acf(taco_stands.set_index("Date"));

# %%
# diff() allows to remove trend from data
taco_stands.set_index("Date")["Taco Stands in LA"].diff()
# Out:
# Date
# 2010-01-01    NaN
# 2010-02-01    3.0
# 2010-03-01    0.0
# 2010-04-01    4.0
# 2010-05-01    5.0
#              ...
# 2029-08-01    8.0
# 2029-09-01   -7.0
# 2029-10-01   -2.0
# 2029-11-01   -1.0
# 2029-12-01   -2.0
# Name: Taco Stands in LA, Length: 240, dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
 
# Need to difference our series to remove trend, slicing off missing value to plot
 
plot_acf(taco_stands["Taco Stands in LA"].diff()[1:]);

# %%
monthly_weather = (
    weather
    .set_index("time")
    .resample("MS")   # MonthStart
    .agg({"temperature": "mean"})
    .reset_index()
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 monthly_weather = (
#       2     weather
#       3     .set_index("time")
# ----> 4     .resample("MS")   # MonthStart
#       5     .agg({"temperature": "mean"})
#       6     .reset_index()
#       7 )
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\resample.py:2335, in get_resampler(obj, **kwds)
#    2331 """
#    2332 Create a TimeGrouper and return our resampler.
#    2333 """
#    2334 tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
# -> 2335 return tg._get_resampler(obj)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\resample.py:2541, in TimeGrouper._get_resampler(self, obj)
#    2533 elif isinstance(ax, TimedeltaIndex):
#    2534     return TimedeltaIndexResampler(
#    2535         obj,
#    2536         timegrouper=self,
#    2537         group_keys=self.group_keys,
#    2538         gpr_index=ax,
#    2539     )
# -> 2541 raise TypeError(
#    2542     "Only valid with DatetimeIndex, "
#    2543     "TimedeltaIndex or PeriodIndex, "
#    2544     f"but got an instance of '{type(ax).__name__}'"
#    2545 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
# Create Trend and Seasonal Variables
 
monthly_weather = monthly_weather.assign(
    trend=range(len(monthly_weather)),
    month=monthly_weather["time"].dt.month
)
 
monthly_weather.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Create Trend and Seasonal Variables
# ----> 3 monthly_weather = monthly_weather.assign(
#       4     trend=range(len(monthly_weather)),
#       5     month=monthly_weather["time"].dt.month
#       6 )
#       8 monthly_weather.head()
#
# NameError: name 'monthly_weather' is not defined

# %%
# Get Seasonal Dummies
 
month_dummies = pd.get_dummies(
    monthly_weather["month"].astype(int),
    prefix="m",
    drop_first=True,
    dtype=int
)
 
monthly_weather = (
    monthly_weather
    .drop(columns=["month"])
    .join(month_dummies)
)
 
# Saugiklis: jei liko True/False stulpelių, paversti į 0/1
bool_cols = monthly_weather.select_dtypes(include="bool").columns
monthly_weather[bool_cols] = monthly_weather[bool_cols].astype(int)
 
monthly_weather.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Get Seasonal Dummies
#       3 month_dummies = pd.get_dummies(
# ----> 4     monthly_weather["month"].astype(int),
#       5     prefix="m",
#       6     drop_first=True,
#       7     dtype=int
#       8 )
#      10 monthly_weather = (
#      11     monthly_weather
#      12     .drop(columns=["month"])
#      13     .join(month_dummies)
#      14 )
#      16 # Saugiklis: jei liko True/False stulpelių, paversti į 0/1
#
# NameError: name 'monthly_weather' is not defined

# %%
# Split Data Based on Time
 
weather_train = monthly_weather.set_index("time").loc[:"2021-09"] #predict final 4 months in dataset
weather_test = monthly_weather.set_index("time").loc["2021-10-31":]
 
weather_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Split Data Based on Time
# ----> 3 weather_train = monthly_weather.set_index("time").loc[:"2021-09"] #predict final 4 months in dataset
#       4 weather_test = monthly_weather.set_index("time").loc["2021-10-31":]
#       6 weather_test
#
# NameError: name 'monthly_weather' is not defined

# %%
# Make Predictions
 
y_test = weather_test["temperature"]
X_test = sm.add_constant(weather_test.iloc[:,1:]) #.drop("trend", axis=1)
 
prediction = model.predict(X_test)
prediction

# %%
# Predictions vs. Actual DataFrame
 
pred_df = pd.DataFrame({"actual": y_test, "predicted": prediction})
 
pred_df

# %%
# Performance Metrics
 
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_absolute_error as mae
 
print(mape(pred_df["actual"], pred_df["predicted"]))
print(mae(pred_df["actual"], pred_df["predicted"]))

# %%
pred_df.plot()

# %%
# Reshape Dataframe into Facebook Prophet Data
 
monthly_weather = (
    weather
    .set_index("time")
    .resample("M")
    .agg(temperature=("temperature", "mean"))
    .reset_index()
)
 
monthly_weather = monthly_weather.rename(columns={"time": "ds", "temperature": "y"})
monthly_weather["ds"] = pd.to_datetime(monthly_weather["ds"])
 
monthly_weather.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6313, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6180, in pandas._libs.tslibs.offsets._validate_to_offset_alias()
#
# ValueError: 'M' is no longer supported for offsets. Please use 'ME' instead.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 6
#       1 # Reshape Dataframe into Facebook Prophet Data
#       3 monthly_weather = (
#       4     weather
#       5     .set_index("time")
# ----> 6     .resample("M")
#       7     .agg(temperature=("temperature", "mean"))
#       8     .reset_index()
#       9 )
#      11 monthly_weather = monthly_weather.rename(columns={"time": "ds", "temperature": "y"})
#      12 monthly_weather["ds"] = pd.to_datetime(monthly_weather["ds"])
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
#    9421 from pandas.core.resample import get_resampler
# -> 9423 return get_resampler(
#    9424     cast("Series | DataFrame", self),
#    9425     freq=rule,
#    9426     label=label,
#    9427     closed=closed,
#    9428     convention=convention,
#    9429     key=on,
#    9430     level=level,
#    9431     origin=origin,
#    9432     offset=offset,
#    9433     group_keys=group_keys,
#    9434 )
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File c:\Users\migle\Desktop\BIT kursai\.venv\Lib\site-packages\pandas\core\resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
#
# ValueError: Invalid frequency: M. Failed to parse with error message: ValueError("'M' is no longer supported for offsets. Please use 'ME' instead.")

# %%
# Split Data
 
monthly_weather_train = monthly_weather.iloc[:-4].copy()
monthly_weather_test  = monthly_weather.iloc[-4:].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Split Data
# ----> 3 monthly_weather_train = monthly_weather.iloc[:-4].copy()
#       4 monthly_weather_test  = monthly_weather.iloc[-4:].copy()
#
# NameError: name 'monthly_weather' is not defined

# %%
# !conda install prophet --y
 
from prophet import Prophet
 
m = Prophet()
m.fit(monthly_weather_train)
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 3
#       1 get_ipython().system('conda install prophet --y')
# ----> 3 from prophet import Prophet
#       5 m = Prophet()
#       6 m.fit(monthly_weather_train)
#
# ModuleNotFoundError: No module named 'prophet'
