# %%
letters = ["a", "b", "c", "d"]

while len(letters) > 0:
    letter = letters.pop(0)
    if letter == "c":
        continue
    else:
        print(letter)
# Out:
# a
# b
# d

# %%
import datetime
