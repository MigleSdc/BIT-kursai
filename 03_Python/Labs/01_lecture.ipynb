# %% [markdown]
# Task nr 2
#
# Write code that performs the following operations on the string "Zen of Python":
# - Prints the last character of the second word
# - Prints the first character of the third word
# - Prints only the first word
# - Prints only the last word
# - Prints the entire phrase in reverse
# - Splits the words and prints them separately
# - Replaces the word "Python" with "Programming" and prints the new sentence
#
# Tip: Use string slicing, and the functions split() and replace().
# The Zen of Python:

# %%
zen_of_python = "Zen of Python"
print(zen_of_python.split(" ")[1][-1])  # f
# TODO
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
# Out:
# f
# Zen of Python
# Zen of Python
# Zen of Python
# Zen of Python
# Zen of Python
# Zen of Python

# %% [markdown]
# Write code that:
# - Allows the user to input numbers a and b (int or float)
# - Prints "a is less than b" if that is true
# - Prints "a is equal to b" if that is true
# - Prints "a is greater than b" if that is true
#   Tip: Use input, if, elif, and else statements

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

if a < b:
    print(f"{a} is less than {b}")
elif a > b:
    print(f"{a} is greater than {b}")
else:
    print(f"{a} is equal to {b}")
# Out:
# 6 is less than 9

# %%
zen_of_python = "Zen of Python"
print(zen_of_python.upper())  # ZEN OF PYTHON
print(zen_of_python.casefold())  # zen of python
print(zen_of_python.capitalize())  # Zen of python
# Count how many letters "o" are in the string
print(zen_of_python.count("o"))  # 2
# Count the index of the first "P" in the string
print(zen_of_python.find("P"))  # 7
# Count the index of the first "o" in the string
print(zen_of_python.find("o"))  # 4
# TODO: Try other functions as well
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
print(zen_of_python)
# Out:
# ZEN OF PYTHON
# zen of python
# Zen of python
# 2
# 7
# 4
# Zen of Python
# Zen of Python
# Zen of Python
# Zen of Python

# %%
x = int(input("Enter the first number: "))
y = int(input("Enter the second number: "))

operation = input("Enter, which mathematical operation should be performed (+ - * /): ")

result = 0.0

if operation == "+":
    result = x + y
elif operation == "-":
    result = x - y
elif operation == "*":
    result = x * y
elif operation == "/":
    result = x / y
else:
    result = "INVALID INPUT"
    
print(f" Result is: {result}")
# Out:
#  Result is: -20
