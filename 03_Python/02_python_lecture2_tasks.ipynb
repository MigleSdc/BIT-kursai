# %% [markdown]
# Python Lecture 2 Tasks
# The tasks use list, dict, for, while, if, elif, else, break, continue, as well as list and dictionary methods like pop(), remove(), reverse(), append(), items(), type().
# 1. Create a list with numbers from 1 to 10. Use a `for` loop and print only even numbers. Use `continue`.
